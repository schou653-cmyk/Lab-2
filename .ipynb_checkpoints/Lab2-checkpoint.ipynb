# %%
def load_stopwords(filepath: str) -> set:
    """Reads a stopwords file into a set of lowercase words."""
    stopwords = set()
    with open(filepath, "r", encoding="utf-8") as file:
        for line in file:
            word = line.strip().lower()
            if word:
                stopwords.add(word)
    return stopwords


def process_document(filepath: str, stopwords: set) -> list:
    """Tokenizes text, strips punctuation, and filters out stopwords."""
    remaining_words = []
    with open(filepath, "r", encoding="utf-8") as file:
        for line in file:
            for word in line.lower().split():
                clean_word = word.strip(".,!?'\":;")
                if clean_word and clean_word not in stopwords:
                    remaining_words.append(clean_word)
    return remaining_words


def compute_term_frequencies(words: list) -> dict:
    """Computes relative term frequencies: count / total_words."""
    if not words:
        return {}
    counts = {}
    for word in words:
        counts[word] = counts.get(word, 0) + 1
    total_words = len(words)
    return {word: count / total_words for word, count in counts.items()}


def run_analysis(stopwords_path: str, doc1_path: str, doc2_path: str):
    stopwords = load_stopwords(stopwords_path)
    doc1_words = process_document(doc1_path, stopwords)
    doc2_words = process_document(doc2_path, stopwords)

    doc1_tf = compute_term_frequencies(doc1_words)
    doc2_tf = compute_term_frequencies(doc2_words)

    set1 = set(doc1_tf.keys())
    set2 = set(doc2_tf.keys())

    common_words = set1.intersection(set2)
    unique_doc1 = {w: doc1_tf[w] for w in (set1 - set2)}
    unique_doc2 = {w: doc2_tf[w] for w in (set2 - set1)}

    print("Remaining Words in Document 1")
    print(doc1_words)
    print("\nRemaining Words in Document 2")
    print(doc2_words)
    print("\nTerm Frequencies for Document 1")
    print(doc1_tf)
    print("\nTerm Frequencies for Document 2")
    print(doc2_tf)
    print("\nCommon words:")
    print(common_words)
    print("\nUnique words in Document 1:")
    print(unique_doc1)
    print("\nUnique words in Document 2:")
    print(unique_doc2)

# %%
# Test 1 from professor's test suite
run_analysis("stopwords4T1.txt", "textA4T1.txt", "textB4T1.txt")
# Out:
# Remaining Words in Document 1
# ['cat', 'small', 'dog', 'big']
#
# Remaining Words in Document 2
# ['dog', 'fast', 'cat', 'slow']
#
# Term Frequencies for Document 1
# {'cat': 0.25, 'small': 0.25, 'dog': 0.25, 'big': 0.25}
#
# Term Frequencies for Document 2
# {'dog': 0.25, 'fast': 0.25, 'cat': 0.25, 'slow': 0.25}
#
# Common words:
# {'dog', 'cat'}
#
# Unique words in Document 1:
# {'big': 0.25, 'small': 0.25}
#
# Unique words in Document 2:
# {'fast': 0.25, 'slow': 0.25}

# %%
# Main analysis for Campbell (textA) and Watts (textB)
run_analysis("stopwords.txt", "textA.txt", "textB.txt")
# Out:
# Remaining Words in Document 1
# ['first', 'step', 'knowledge', 'wonder', 'mystery', 'life', 'recognition', 'monstrous', 'nature', 'earthly', 'human', 'realm', 'well', 'glory', 'realization', 'cannot', 'changed', 'think', 'know', 'universe', 'could', 'created', 'without', 'pain', 'without', 'sorrow', 'without', 'time', 'without', 'death', 'unfit', 'illumination', 'proceed', 'life', 'following', 'path', 'birds', 'shit', "don't", 'bother', 'brush', 'getting', 'comedic', 'view', 'situation', 'gives', 'spiritual', 'distance', 'sense', 'humor', 'saves', 'joseph', 'campbell']
#
# Remaining Words in Document 2
# ['true', 'splendor', 'science', 'much', 'names', 'classifies', 'records', 'predicts', 'observes', 'desires', 'know', 'facts', 'whatever', 'may', 'turn', 'however', 'much', 'may', 'confuse', 'facts', 'conventions', 'reality', 'arbitrary', 'divisions', 'openness', 'sincerity', 'mind', 'bears', 'resemblance', 'religion', 'understood', 'deeper', 'sense', 'greater', 'scientist', 'impressed', 'ignorance', 'reality', 'realizes', 'laws', 'labels', 'descriptions', 'definitions', 'products', 'thought', 'help', 'use', 'world', 'purposes', 'devising', 'rather', 'understand', 'explain', 'analyzes', 'universe', 'infinitesimals', 'things', 'finds', 'classify', 'perceives', 'relativity', 'classification', 'know', 'seems', 'increase', 'geometric', 'progression', 'knows', 'steadily', 'approaches', 'point', 'unknown', 'mere', 'blank', 'space', 'web', 'words', 'window', 'mind', 'window', 'whose', 'name', 'ignorance', 'wonder', 'alan', 'watts']
#
# Term Frequencies for Document 1
# {'first': 0.018867924528301886, 'step': 0.018867924528301886, 'knowledge': 0.018867924528301886, 'wonder': 0.018867924528301886, 'mystery': 0.018867924528301886, 'life': 0.03773584905660377, 'recognition': 0.018867924528301886, 'monstrous': 0.018867924528301886, 'nature': 0.018867924528301886, 'earthly': 0.018867924528301886, 'human': 0.018867924528301886, 'realm': 0.018867924528301886, 'well': 0.018867924528301886, 'glory': 0.018867924528301886, 'realization': 0.018867924528301886, 'cannot': 0.018867924528301886, 'changed': 0.018867924528301886, 'think': 0.018867924528301886, 'know': 0.018867924528301886, 'universe': 0.018867924528301886, 'could': 0.018867924528301886, 'created': 0.018867924528301886, 'without': 0.07547169811320754, 'pain': 0.018867924528301886, 'sorrow': 0.018867924528301886, 'time': 0.018867924528301886, 'death': 0.018867924528301886, 'unfit': 0.018867924528301886, 'illumination': 0.018867924528301886, 'proceed': 0.018867924528301886, 'following': 0.018867924528301886, 'path': 0.018867924528301886, 'birds': 0.018867924528301886, 'shit': 0.018867924528301886, "don't": 0.018867924528301886, 'bother': 0.018867924528301886, 'brush': 0.018867924528301886, 'getting': 0.018867924528301886, 'comedic': 0.018867924528301886, 'view': 0.018867924528301886, 'situation': 0.018867924528301886, 'gives': 0.018867924528301886, 'spiritual': 0.018867924528301886, 'distance': 0.018867924528301886, 'sense': 0.018867924528301886, 'humor': 0.018867924528301886, 'saves': 0.018867924528301886, 'joseph': 0.018867924528301886, 'campbell': 0.018867924528301886}
#
# Term Frequencies for Document 2
# {'true': 0.011627906976744186, 'splendor': 0.011627906976744186, 'science': 0.011627906976744186, 'much': 0.023255813953488372, 'names': 0.011627906976744186, 'classifies': 0.011627906976744186, 'records': 0.011627906976744186, 'predicts': 0.011627906976744186, 'observes': 0.011627906976744186, 'desires': 0.011627906976744186, 'know': 0.023255813953488372, 'facts': 0.023255813953488372, 'whatever': 0.011627906976744186, 'may': 0.023255813953488372, 'turn': 0.011627906976744186, 'however': 0.011627906976744186, 'confuse': 0.011627906976744186, 'conventions': 0.011627906976744186, 'reality': 0.023255813953488372, 'arbitrary': 0.011627906976744186, 'divisions': 0.011627906976744186, 'openness': 0.011627906976744186, 'sincerity': 0.011627906976744186, 'mind': 0.023255813953488372, 'bears': 0.011627906976744186, 'resemblance': 0.011627906976744186, 'religion': 0.011627906976744186, 'understood': 0.011627906976744186, 'deeper': 0.011627906976744186, 'sense': 0.011627906976744186, 'greater': 0.011627906976744186, 'scientist': 0.011627906976744186, 'impressed': 0.011627906976744186, 'ignorance': 0.023255813953488372, 'realizes': 0.011627906976744186, 'laws': 0.011627906976744186, 'labels': 0.011627906976744186, 'descriptions': 0.011627906976744186, 'definitions': 0.011627906976744186, 'products': 0.011627906976744186, 'thought': 0.011627906976744186, 'help': 0.011627906976744186, 'use': 0.011627906976744186, 'world': 0.011627906976744186, 'purposes': 0.011627906976744186, 'devising': 0.011627906976744186, 'rather': 0.011627906976744186, 'understand': 0.011627906976744186, 'explain': 0.011627906976744186, 'analyzes': 0.011627906976744186, 'universe': 0.011627906976744186, 'infinitesimals': 0.011627906976744186, 'things': 0.011627906976744186, 'finds': 0.011627906976744186, 'classify': 0.011627906976744186, 'perceives': 0.011627906976744186, 'relativity': 0.011627906976744186, 'classification': 0.011627906976744186, 'seems': 0.011627906976744186, 'increase': 0.011627906976744186, 'geometric': 0.011627906976744186, 'progression': 0.011627906976744186, 'knows': 0.011627906976744186, 'steadily': 0.011627906976744186, 'approaches': 0.011627906976744186, 'point': 0.011627906976744186, 'unknown': 0.011627906976744186, 'mere': 0.011627906976744186, 'blank': 0.011627906976744186, 'space': 0.011627906976744186, 'web': 0.011627906976744186, 'words': 0.011627906976744186, 'window': 0.023255813953488372, 'whose': 0.011627906976744186, 'name': 0.011627906976744186, 'wonder': 0.011627906976744186, 'alan': 0.011627906976744186, 'watts': 0.011627906976744186}
#
# Common words:
# {'sense', 'know', 'wonder', 'universe'}
#
# Unique words in Document 1:
# {'without': 0.07547169811320754, 'glory': 0.018867924528301886, 'cannot': 0.018867924528301886, 'comedic': 0.018867924528301886, 'birds': 0.018867924528301886, 'following': 0.018867924528301886, 'shit': 0.018867924528301886, 'death': 0.018867924528301886, "don't": 0.018867924528301886, 'situation': 0.018867924528301886, 'created': 0.018867924528301886, 'nature': 0.018867924528301886, 'pain': 0.018867924528301886, 'illumination': 0.018867924528301886, 'joseph': 0.018867924528301886, 'knowledge': 0.018867924528301886, 'campbell': 0.018867924528301886, 'could': 0.018867924528301886, 'proceed': 0.018867924528301886, 'gives': 0.018867924528301886, 'first': 0.018867924528301886, 'realization': 0.018867924528301886, 'recognition': 0.018867924528301886, 'spiritual': 0.018867924528301886, 'humor': 0.018867924528301886, 'saves': 0.018867924528301886, 'view': 0.018867924528301886, 'earthly': 0.018867924528301886, 'realm': 0.018867924528301886, 'well': 0.018867924528301886, 'bother': 0.018867924528301886, 'changed': 0.018867924528301886, 'mystery': 0.018867924528301886, 'monstrous': 0.018867924528301886, 'time': 0.018867924528301886, 'human': 0.018867924528301886, 'step': 0.018867924528301886, 'getting': 0.018867924528301886, 'think': 0.018867924528301886, 'distance': 0.018867924528301886, 'brush': 0.018867924528301886, 'path': 0.018867924528301886, 'sorrow': 0.018867924528301886, 'unfit': 0.018867924528301886, 'life': 0.03773584905660377}
#
# Unique words in Document 2:
# {'religion': 0.011627906976744186, 'web': 0.011627906976744186, 'world': 0.011627906976744186, 'infinitesimals': 0.011627906976744186, 'sincerity': 0.011627906976744186, 'turn': 0.011627906976744186, 'understood': 0.011627906976744186, 'use': 0.011627906976744186, 'mere': 0.011627906976744186, 'laws': 0.011627906976744186, 'records': 0.011627906976744186, 'thought': 0.011627906976744186, 'greater': 0.011627906976744186, 'understand': 0.011627906976744186, 'conventions': 0.011627906976744186, 'words': 0.011627906976744186, 'true': 0.011627906976744186, 'bears': 0.011627906976744186, 'space': 0.011627906976744186, 'classify': 0.011627906976744186, 'increase': 0.011627906976744186, 'facts': 0.023255813953488372, 'however': 0.011627906976744186, 'splendor': 0.011627906976744186, 'watts': 0.011627906976744186, 'impressed': 0.011627906976744186, 'purposes': 0.011627906976744186, 'relativity': 0.011627906976744186, 'perceives': 0.011627906976744186, 'predicts': 0.011627906976744186, 'approaches': 0.011627906976744186, 'window': 0.023255813953488372, 'help': 0.011627906976744186, 'arbitrary': 0.011627906976744186, 'scientist': 0.011627906976744186, 'much': 0.023255813953488372, 'alan': 0.011627906976744186, 'deeper': 0.011627906976744186, 'labels': 0.011627906976744186, 'desires': 0.011627906976744186, 'observes': 0.011627906976744186, 'whose': 0.011627906976744186, 'whatever': 0.011627906976744186, 'point': 0.011627906976744186, 'rather': 0.011627906976744186, 'seems': 0.011627906976744186, 'mind': 0.023255813953488372, 'reality': 0.023255813953488372, 'confuse': 0.011627906976744186, 'steadily': 0.011627906976744186, 'explain': 0.011627906976744186, 'knows': 0.011627906976744186, 'things': 0.011627906976744186, 'divisions': 0.011627906976744186, 'blank': 0.011627906976744186, 'science': 0.011627906976744186, 'classifies': 0.011627906976744186, 'devising': 0.011627906976744186, 'openness': 0.011627906976744186, 'products': 0.011627906976744186, 'unknown': 0.011627906976744186, 'may': 0.023255813953488372, 'descriptions': 0.011627906976744186, 'finds': 0.011627906976744186, 'classification': 0.011627906976744186, 'geometric': 0.011627906976744186, 'resemblance': 0.011627906976744186, 'definitions': 0.011627906976744186, 'name': 0.011627906976744186, 'realizes': 0.011627906976744186, 'names': 0.011627906976744186, 'analyzes': 0.011627906976744186, 'progression': 0.011627906976744186, 'ignorance': 0.023255813953488372}

# %% [markdown]
# ### Analysis & Key Findings
# - **Shared Vocabulary:** The intersection between both passages focuses on universal philosophical inquiry: `{'sense', 'know', 'wonder', 'universe'}`.
# - **Campbell's Focus (Document 1):** Vocabulary centers on human existence, emotional endurance, and comedic detachment (`life`, `pain`, `sorrow`, `humor`).
# - **Watts' Focus (Document 2):** Vocabulary centers on scientific observation, epistemology, and systemic inquiry (`science`, `classify`, `reality`, `ignorance`).
# -
